# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = []
x2 = []
y = []
y2 = []

for i in range(1500):
    r = 1000
    x.append(-i)
    x2.append(i)
    y.append(np.sqrt(r ** 2 - i ** 2))
    y2.append(-np.sqrt(r ** 2 - i ** 2))
    
plt.figure(figsize = (7, 7))    
plt.plot(x, y, color='g')
plt.plot(x, y2, color='g')
plt.plot(x2, y2, color='g')
plt.plot(x2, y, color='g')
plt.axis('scaled')
plt.show()
# Out:
# C:\Users\Eleanor\AppData\Local\Temp/ipykernel_8020/3628266466.py:10: RuntimeWarning: invalid value encountered in sqrt
#   y.append(np.sqrt(r ** 2 - i ** 2))
# C:\Users\Eleanor\AppData\Local\Temp/ipykernel_8020/3628266466.py:11: RuntimeWarning: invalid value encountered in sqrt
#   y2.append(-np.sqrt(r ** 2 - i ** 2))

# %%
x = []
x2 = []
y = []
y2 = []

for i in range(1000):
    a = 40
    b = 20
    x.append(-i)
    x2.append(i)
    y.append(np.sqrt(b ** 2 - (b ** 2 * (i ** 2 / a ** 2))))
    y2.append(-np.sqrt(b ** 2 - (b ** 2 * (i ** 2 / a ** 2))))

plt.plot(x, y, color='b')
plt.plot(x, y2, color='b')
plt.plot(x2, y2, color='b')
plt.plot(x2, y, color='b')
plt.axis('scaled')
plt.show()
# Out:
# C:\Users\Eleanor\AppData\Local\Temp/ipykernel_8020/3400937155.py:11: RuntimeWarning: invalid value encountered in sqrt
#   y.append(np.sqrt(b ** 2 - (b ** 2 * (i ** 2 / a ** 2))))
# C:\Users\Eleanor\AppData\Local\Temp/ipykernel_8020/3400937155.py:12: RuntimeWarning: invalid value encountered in sqrt
#   y2.append(-np.sqrt(b ** 2 - (b ** 2 * (i ** 2 / a ** 2))))

# %%
x = []
x2 = []
y = []
y2 = []

for i in range(1000):
    a = 600
    b = 300
    x.append(-i)
    x2.append(i)
    y.append(np.sqrt(b ** 2 + (b ** 2 * (i ** 2 / a ** 2))))
    y2.append(-np.sqrt(b ** 2 + (b ** 2 * (i ** 2 / a ** 2))))
    
plt.plot(x, y, color='r')
plt.plot(x, y2, color='r')
plt.plot(x2, y2, color='r')
plt.plot(x2, y, color='r')
plt.axis('scaled')
plt.show()
