# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = figure(figsize = (8, 8))
ax = Axes3D(fig)
X = np.arange(-25, 25, 2)
Y = np.arange(-25, 25, 2)

X, Y = np.meshgrid(X, Y)

Z = 9*X + 200
Z2 = 9*X + 10
ax.plot_wireframe(X, Y, Z, linestyle='--', linewidth=1)
ax.plot_wireframe(X, Y, Z2,colors='red')


show()
# Out:
# C:\Users\Eleanor\AppData\Local\Temp/ipykernel_5976/1634140201.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
fig = figure(figsize = (18, 18))
ax = Axes3D(fig)

a = 40
b = 70

X, Y = np.meshgrid((np.arange(-15, 15, 2)), (np.arange(-15, 15, 2)))

Z = b ** 2 + (b ** 2 * (X ** 2 / a ** 2))
Z1 = -(b ** 2 + (b ** 2 * (X ** 2 / a ** 2)))
Z2 = 2*a*X ** np.cos(40) + np.sqrt(2*a*X ** np.cos(40))
ax.plot_surface(X, Y, Z,  linewidth=1, color='b')
ax.plot_surface(X, Y, Z1,  linewidth=1, color='w')


u = np.linspace(0,2*np.pi, 32)
v = np.linspace(0, np.pi, 16)

x = 10 * np.outer(np.cos(u), np.sin(v))
y = 50 * np.outer(np.sin(u), np.sin(v))
z = -100 * np.outer(np.ones(np.size(u)), np.cos(v))

ax.plot_surface(x, y, z, rstride=4, cstride=4, color='r')


show()
# Out:
# C:\Users\Eleanor\AppData\Local\Temp/ipykernel_5976/3003619098.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\Eleanor\AppData\Local\Temp/ipykernel_5976/3003619098.py:11: RuntimeWarning: invalid value encountered in power
#   Z2 = 2*a*X ** np.cos(40) + np.sqrt(2*a*X ** np.cos(40))
