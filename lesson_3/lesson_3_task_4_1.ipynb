# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
fig = figure(figsize = (10, 10))
ax = Axes3D(fig)
X = np.arange(-10, 10, 2)
Y = np.arange(-10, 10, 2)

X, Y = np.meshgrid(X, Y)

Z = 2*X + 3*Y + 200
Z2 = 2*X + 3*Y
ax.plot_wireframe(X, Y, Z, label='Ax + By + Cz + D = 0', linestyle='--', linewidth=1)
ax.plot_wireframe(X, Y, Z2,colors='green',  label='Ax + By + Cz = 0')
ax.scatter(0, 0, 0,'z',50,'red', label='Координата: 0; 0')
plt.legend(frameon=False)
show()
# Out:
# C:\Users\Eleanor\AppData\Local\Temp/ipykernel_2132/1021415953.py:4: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
